# %%
print("My notebook")
# Out:
# My notebook

# %%
print(1+1)
# Out:
# 2

# %%
print("Option + enter adds a new cell between all of it")
# Out:
# Option + enter adds a new cell between all of it

# %%
"Shift + enter"
# Out:
# 'Shift + enter'

# %%
while true:
    print("This will run forever")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-d9bf6372d4bd> in <module>
# ----> 1 while true:
#       2     print("This will run forever")
#
# NameError: name 'true' is not defined

# %%
while True:
    print("No stop")
# Out:
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# No stop
# ...

# %%
This
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3848b1a72629> in <module>
# ----> 1 This
#
# NameError: name 'This' is not defined
